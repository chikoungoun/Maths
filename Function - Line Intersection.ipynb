# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 1000)
f = np.arange(0, 1000)
g = np.sin(np.arange(0, 10, 0.01) * 2) * 1000

plt.plot(x, f, '-')
plt.plot(x, g, '-')

# %%
idx = np.argwhere(np.diff(np.sign(f - g))).flatten()

# %%
idx
# Out:
# array([  0, 149, 331, 448, 664, 743], dtype=int64)

# %%
plt.plot(x, f, '-')
plt.plot(x, g, '-')
plt.plot(x[idx], f[idx], 'ro')

# %% [markdown]
# ### Project vertical line
# value of 210

# %%
plt.plot(x, f, '-')
plt.plot(x, g, '-')
plt.plot(x[idx], f[idx], 'ro')
plt.axvline(x=210, linestyle=':', color='red')

# %%
# 
ex = np.argwhere(np.diff(np.sign(x - 210))).flatten()
ex
# Out:
# array([209, 210], dtype=int64)

# %%
plt.plot(x, g, '-')
plt.plot(x[ex], g[ex], 'ro')
plt.axvline(x=210, linestyle=':', color='red')

# %% [markdown]
# ## np.sign
# Returns an element-wise indication of the sign of a number.

# %%
print(np.sign(-2))
print(np.sign([-5., 4.5]))
# Out:
# -1
# [-1.  1.]

# %% [markdown]
# ## np.flatten
# return a copy of a given array in such a way that it is collapsed into one dimension.
# flatten can take several arguments .flatten(X) :
# * 'C': This is to flatten the array in row-major order.
# * 'F': This is to flatten the array in column-major order.
# * 'A': This is to flatten the array in column-major order, if the input array is Fortran contiguous in memory, and row-major order if otherwise.
# * 'K': This is to flatten the array in the order in which its elements occur in memory.

# %%
np.array([[1,2,3],[4,5,6]])
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.array([[1,2,3],[4,5,6]]).flatten()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# ## np.diff
# Calculate the n-th discrete difference along the given axis.

# %%
x = np.array([1, 2, 4, 7, 0])

np.diff(x)
# Out:
# array([ 1,  2,  3, -7])

# %% [markdown]
# ## np.argwhere
# find the indices of elements in an array that satisfy a given condition. The function returns a list of tuples, where each tuple contains the indices of the elements that meet the specified condition.

# %%
x = np.array([1, 2, 4, 7, 0])
np.argwhere(x > 2)
# Out:
# array([[2],
#        [3]], dtype=int64)

# %%
x = np.arange(6).reshape(2,3)
x
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
np.argwhere(x <= 3)
# Out:
# array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0]], dtype=int64)
